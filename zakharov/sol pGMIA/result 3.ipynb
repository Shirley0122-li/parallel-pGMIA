# %%
import pickle
# package for plotting
import matplotlib.pyplot as plt
import numpy as np
output_vs_time = np.zeros([1200,100])
output_vs_num = np.zeros([10000,100])

for seed in range(1, 101):
    # open a file, where you stored the pickled data
    file = open(f'seed{seed}total', 'rb')

    # dump information to that file
    cur = pickle.load(file)
    [cur_opt_sol, opt_true_val, cur_opt_val, cur_num_sampled, cur_num_reps, \
        cur_opt_reg, cur_opt_sol_reg, cur_max_CEI_reg, cur_reg_CEI_max_val, cur_total_opt_val, \
            cur_sampled_in_opt_reg, cur_total_max_CEI, cur_run_time] = cur

    # close the file
    file.close()

    for i in range(1200):
        for j in range(len(opt_true_val)):
            if opt_true_val[j, 1] > i:
                output_vs_time[i, seed-1] = opt_true_val[j, 0]
                break

    for i in range(10000):
        for j in range(len(opt_true_val)):
            if opt_true_val[j, 2] >= i:
                output_vs_num[i, seed-1] = opt_true_val[j, 0]
                break

# %%
sol_pGMIA_output_vs_time_mean = np.average(output_vs_time, axis = 1)
sol_pGMIA_output_vs_time_var = np.std(output_vs_time, axis = 1)
plt.plot(sol_pGMIA_output_vs_time_mean)

# %%
sol_pGMIA_output_vs_num_mean = np.average(output_vs_num, axis = 1)
sol_pGMIA_output_vs_num_var = np.std(output_vs_num, axis = 1)
plt.plot(sol_pGMIA_output_vs_num_mean)

# %%
file = open('sol_result', 'wb')
pickle.dump([sol_pGMIA_output_vs_time_mean, sol_pGMIA_output_vs_time_var, \
    sol_pGMIA_output_vs_num_mean, sol_pGMIA_output_vs_num_var], file)
file.close()

# %%
import pickle
# package for plotting
import matplotlib.pyplot as plt

# open a file, where you stored the pickled data
file = open('c4p5iter5_UCB', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c4p5iter5_UCB, running_time_c4p5iter5, number_sampled_c4p5iter5, \
    output_mean_c4p5iter5, output_var_c4p5iter5, output_vs_num_c4p5iter5_UCB, \
        output_vs_num_mean_c4p5iter5_UCB, output_vs_num_var_c4p5iter5_UCB] = cur

# close the file
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/hm/7nf3ljf15m50d7c6x0d77zcc0000gn/T/ipykernel_3213/818199217.py in <module>
#       4
#       5 # open a file, where you stored the pickled data
# ----> 6 file = open('c4p5iter5_UCB', 'rb')
#       7
#       8 # dump information to that file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c4p5iter5_UCB'

# %%
import numpy as np

max_num = 2000
x = np.arange(0,2000)
fig,ax = plt.subplots()
ax.plot(output_vs_num_mean_c4p5iter5[0:max_num], label = 'UCB', color='tab:blue')
ax.fill_between(x,output_vs_num_mean_c4p5iter5[0:max_num]-2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c4p5iter5[0:max_num]+2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:blue')
ax.plot(output_vs_num_mean_c4p5iter5_UCB[0:max_num], label = 'CEI', color='tab:orange')
ax.fill_between(x,output_vs_num_mean_c4p5iter5_UCB[0:max_num]-2*output_vs_num_var_c4p5iter5_UCB[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c4p5iter5_UCB[0:max_num]+2*output_vs_num_var_c4p5iter5_UCB[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:orange')

ax.set_xlabel('Number of simulations / 10')
ax.set_ylabel('True optimality gap')
ax.set_ylim([0,15])

ax.legend()
plt.savefig('comparison_num.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hm/7nf3ljf15m50d7c6x0d77zcc0000gn/T/ipykernel_3213/351183222.py in <module>
#       5 fig,ax = plt.subplots()
#       6 ax.plot(output_vs_num_mean_c4p5iter5[0:max_num], label = 'UCB', color='tab:blue')
# ----> 7 ax.fill_between(x,output_vs_num_mean_c4p5iter5[0:max_num]-2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
#       8     output_vs_num_mean_c4p5iter5[0:max_num]+2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
#       9         alpha=0.2, facecolor='tab:blue')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
# ...

# %%
# open a file, where you stored the pickled data
file = open('c4p5iter10', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c4p5iter10, running_time_c4p5iter10, number_sampled_c4p5iter10, \
    output_mean_c4p5iter10, output_var_c4p5iter10, output_vs_num_c4p5iter10, \
        output_vs_num_mean_c4p5iter10, output_vs_num_var_c4p5iter10] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c4p10iter5', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c4p10iter5, running_time_c4p10iter5, number_sampled_c4p10iter5, \
    output_mean_c4p10iter5, output_var_c4p10iter5, output_vs_num_c4p10iter5, \
        output_vs_num_mean_c4p10iter5, output_vs_num_var_c4p10iter5] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c4p10iter10', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c4p10iter10, running_time_c4p10iter10, number_sampled_c4p10iter10, \
    output_mean_c4p10iter10, output_var_c4p10iter10, output_vs_num_c4p10iter10, \
        output_vs_num_mean_c4p10iter10, output_vs_num_var_c4p10iter10] = cur

# close the file
file.close()

# %%
import pickle
# open a file, where you stored the pickled data
file = open('c8p5iter5', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p5iter5, running_time_c8p5iter5, number_sampled_c8p5iter5, \
    output_mean_c8p5iter5, output_var_c8p5iter5, output_vs_num_c8p5iter5, \
        output_vs_num_mean_c8p5iter5, output_vs_num_var_c8p5iter5] = cur

# close the file
file.close()


# open a file, where you stored the pickled data
file = open('c8p5iter10', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p5iter10, running_time_c8p5iter10, number_sampled_c8p5iter10, \
    output_mean_c8p5iter10, output_var_c8p5iter10, output_vs_num_c8p5iter10, \
        output_vs_num_mean_c8p5iter10, output_vs_num_var_c8p5iter10] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c8p10iter5', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p10iter5, running_time_c8p10iter5, number_sampled_c8p10iter5, \
    output_mean_c8p10iter5, output_var_c8p10iter5, output_vs_num_c8p10iter5, \
        output_vs_num_mean_c8p10iter5, output_vs_num_var_c8p10iter5] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c8p10iter10', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p10iter10, running_time_c8p10iter10, number_sampled_c8p10iter10, \
    output_mean_c8p10iter10, output_var_c8p10iter10, output_vs_num_c8p10iter10, \
        output_vs_num_mean_c8p10iter10, output_vs_num_var_c8p10iter10] = cur

# close the file
file.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
max_num = 101
x = np.arange(0,101)
fig,ax = plt.subplots()
# ax.plot(output_vs_num_mean_c4p5iter5[0:max_num], label = 'c=4,p=5,iter=5', color='tab:blue')
# ax.fill_between(x,output_vs_num_mean_c4p5iter5[0:max_num]-2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
#     output_vs_num_mean_c4p5iter5[0:max_num]+2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
#         alpha=0.2, facecolor='tab:blue')
# ax.plot(output_vs_num_mean_c4p5iter10[0:max_num], label = 'c=4,p=5,iter=10', color='tab:orange')
# ax.fill_between(x,output_vs_num_mean_c4p5iter10[0:max_num]-2*output_vs_num_var_c4p5iter10[0:max_num]/np.sqrt(100), \
#     output_vs_num_mean_c4p5iter10[0:max_num]+2*output_vs_num_var_c4p5iter10[0:max_num]/np.sqrt(100), \
#         alpha=0.2, facecolor='tab:orange')
# ax.plot(output_vs_num_mean_c4p10iter5[0:max_num], label = 'c=4,p=10,iter=5', color='tab:green')
# ax.fill_between(x,output_vs_num_mean_c4p10iter5[0:max_num]-2*output_vs_num_var_c4p10iter5[0:max_num]/np.sqrt(100), \
#     output_vs_num_mean_c4p10iter5[0:max_num]+2*output_vs_num_var_c4p10iter5[0:max_num]/np.sqrt(100), \
#         alpha=0.2, facecolor='tab:green')
# ax.plot(output_vs_num_mean_c4p10iter10[0:max_num], label = 'c=4,p=10,iter=10', color='tab:red')
# ax.fill_between(x,output_vs_num_mean_c4p10iter10[0:max_num]-2*output_vs_num_var_c4p10iter10[0:max_num]/np.sqrt(100), \
#     output_vs_num_mean_c4p10iter10[0:max_num]+2*output_vs_num_var_c4p10iter10[0:max_num]/np.sqrt(100), \
#         alpha=0.2, facecolor='tab:red')
ax.plot(output_vs_num_mean_c8p5iter5[0:max_num], label = 'p=5,iter=5', color='dodgerblue')
ax.fill_between(x,output_vs_num_mean_c8p5iter5[0:max_num]-2*output_vs_num_var_c8p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p5iter5[0:max_num]+2*output_vs_num_var_c8p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='dodgerblue')
ax.plot(output_vs_num_mean_c8p5iter10[0:max_num], label = 'p=5,iter=10', linestyle='--', color='darkorange')
ax.fill_between(x,output_vs_num_mean_c8p5iter10[0:max_num]-2*output_vs_num_var_c8p5iter10[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p5iter10[0:max_num]+2*output_vs_num_var_c8p5iter10[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='darkorange')
ax.plot(output_vs_num_mean_c8p10iter10[0:max_num], label = 'p=10,iter=5', linestyle='-.', color='forestgreen')
ax.fill_between(x,output_vs_num_mean_c8p10iter10[0:max_num]-2*output_vs_num_var_c8p10iter10[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p10iter10[0:max_num]+2*output_vs_num_var_c8p10iter10[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='forestgreen')
ax.plot(output_vs_num_mean_c8p10iter5[0:max_num], label = 'p=10,iter=10', linestyle=':', color='deeppink')
ax.fill_between(x,output_vs_num_mean_c8p10iter5[0:max_num]-2*output_vs_num_var_c8p10iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p10iter5[0:max_num]+2*output_vs_num_var_c8p10iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='deeppink')

ax.set_xlabel('Wallclock time (seconds)', fontsize=15)
ax.set_ylabel('True Optimality Gap', fontsize=15)
ax.set_ylim([0,30])
ax.set_xlim([0,100])

ax.legend(prop={'size':15})
plt.savefig('comparison_num.png')

# %%
# open a file, where you stored the pickled data
file = open('c8p5iter5_num', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p5iter5, running_time_c8p5iter5, number_sampled_c8p5iter5, \
    output_mean_c8p5iter5, output_var_c8p5iter5, output_vs_num_c8p5iter5, \
        output_vs_num_mean_c8p5iter5, output_vs_num_var_c8p5iter5] = cur

# close the file
file.close()


# open a file, where you stored the pickled data
file = open('c8p5iter10_num', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p5iter10, running_time_c8p5iter10, number_sampled_c8p5iter10, \
    output_mean_c8p5iter10, output_var_c8p5iter10, output_vs_num_c8p5iter10, \
        output_vs_num_mean_c8p5iter10, output_vs_num_var_c8p5iter10] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c8p10iter5_num', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p10iter5, running_time_c8p10iter5, number_sampled_c8p10iter5, \
    output_mean_c8p10iter5, output_var_c8p10iter5, output_vs_num_c8p10iter5, \
        output_vs_num_mean_c8p10iter5, output_vs_num_var_c8p10iter5] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c8p10iter10_num', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p10iter10, running_time_c8p10iter10, number_sampled_c8p10iter10, \
    output_mean_c8p10iter10, output_var_c8p10iter10, output_vs_num_c8p10iter10, \
        output_vs_num_mean_c8p10iter10, output_vs_num_var_c8p10iter10] = cur

# close the file
file.close()

# %%
import numpy as np

max_num = 161
x = np.arange(0,161)
fig,ax = plt.subplots()
# ax.plot(output_vs_num_mean_c4p5iter5[0:max_num], label = 'c=4,p=5,iter=5', color='tab:blue')
# ax.fill_between(x,output_vs_num_mean_c4p5iter5[0:max_num]-2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
#     output_vs_num_mean_c4p5iter5[0:max_num]+2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
#         alpha=0.2, facecolor='tab:blue')
# ax.plot(output_vs_num_mean_c4p5iter10[0:max_num], label = 'c=4,p=5,iter=10', color='tab:orange')
# ax.fill_between(x,output_vs_num_mean_c4p5iter10[0:max_num]-2*output_vs_num_var_c4p5iter10[0:max_num]/np.sqrt(100), \
#     output_vs_num_mean_c4p5iter10[0:max_num]+2*output_vs_num_var_c4p5iter10[0:max_num]/np.sqrt(100), \
#         alpha=0.2, facecolor='tab:orange')
# ax.plot(output_vs_num_mean_c4p10iter5[0:max_num], label = 'c=4,p=10,iter=5', color='tab:green')
# ax.fill_between(x,output_vs_num_mean_c4p10iter5[0:max_num]-2*output_vs_num_var_c4p10iter5[0:max_num]/np.sqrt(100), \
#     output_vs_num_mean_c4p10iter5[0:max_num]+2*output_vs_num_var_c4p10iter5[0:max_num]/np.sqrt(100), \
#         alpha=0.2, facecolor='tab:green')
# ax.plot(output_vs_num_mean_c4p10iter10[0:max_num], label = 'c=4,p=10,iter=10', color='tab:red')
# ax.fill_between(x,output_vs_num_mean_c4p10iter10[0:max_num]-2*output_vs_num_var_c4p10iter10[0:max_num]/np.sqrt(100), \
#     output_vs_num_mean_c4p10iter10[0:max_num]+2*output_vs_num_var_c4p10iter10[0:max_num]/np.sqrt(100), \
#         alpha=0.2, facecolor='tab:red')
ax.plot(output_vs_num_mean_c8p5iter5[0:max_num], label = 'p=5,iter=5', color='dodgerblue')
ax.fill_between(x,output_vs_num_mean_c8p5iter5[0:max_num]-2*output_vs_num_var_c8p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p5iter5[0:max_num]+2*output_vs_num_var_c8p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='dodgerblue')
ax.plot(output_vs_num_mean_c8p5iter10[0:max_num], label = 'p=5,iter=10', linestyle='--', color='darkorange')
ax.fill_between(x,output_vs_num_mean_c8p5iter10[0:max_num]-2*output_vs_num_var_c8p5iter10[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p5iter10[0:max_num]+2*output_vs_num_var_c8p5iter10[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='darkorange')
ax.plot(output_vs_num_mean_c8p10iter5[0:max_num], label = 'p=10,iter=5', linestyle='-.', color='forestgreen')
ax.fill_between(x,output_vs_num_mean_c8p10iter5[0:max_num]-2*output_vs_num_var_c8p10iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p10iter5[0:max_num]+2*output_vs_num_var_c8p10iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='forestgreen')
ax.plot(output_vs_num_mean_c8p10iter10[0:max_num], label = 'p=10,iter=10', linestyle=':', color='deeppink')
ax.fill_between(x,output_vs_num_mean_c8p10iter10[0:max_num]-2*output_vs_num_var_c8p10iter10[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p10iter10[0:max_num]+2*output_vs_num_var_c8p10iter10[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='deeppink')

ax.set_xlabel('Number of simulations',fontsize=15)
ax.set_ylabel('True Optimality Gap',fontsize=15)
ax.set_ylim([0,30])
ax.set_xlim([0,160])

ax.legend(prop={'size':15})
plt.savefig('comparison_num.png')

# %%
# open a file, where you stored the pickled data
file = open('c8p5iter5', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c8p5iter5, running_time_c8p5iter5, number_sampled_c8p5iter5, \
    output_mean_c8p5iter5, output_var_c8p5iter5, output_vs_num_c8p5iter5, \
        output_vs_num_mean_c8p5iter5, output_vs_num_var_c8p5iter5] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c16p5iter5', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c16p5iter5, running_time_c16p5iter5, number_sampled_c16p5iter5, \
    output_mean_c16p5iter5, output_var_c16p5iter5, output_vs_num_c16p5iter5, \
        output_vs_num_mean_c16p5iter5, output_vs_num_var_c16p5iter5] = cur

# close the file
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/hm/7nf3ljf15m50d7c6x0d77zcc0000gn/T/ipykernel_8131/2046600489.py in <module>
#      12
#      13 # open a file, where you stored the pickled data
# ---> 14 file = open('c16p5iter5', 'rb')
#      15
#      16 # dump information to that file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c16p5iter5'

# %%
# open a file, where you stored the pickled data
file = open('c32p5iter5', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c32p5iter5, running_time_c32p5iter5, number_sampled_c32p5iter5, \
    output_mean_c32p5iter5, output_var_c32p5iter5, output_vs_num_c32p5iter5, \
        output_vs_num_mean_c32p5iter5, output_vs_num_var_c32p5iter5] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c32p5iter10', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c32p5iter10, running_time_c32p5iter10, number_sampled_c32p5iter10, \
    output_mean_c32p5iter10, output_var_c32p5iter10, output_vs_num_c32p5iter10, \
        output_vs_num_mean_c32p5iter10, output_vs_num_var_c32p5iter10] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c32p10iter5', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c32p10iter5, running_time_c32p10iter5, number_sampled_c32p10iter5, \
    output_mean_c32p10iter5, output_var_c32p10iter5, output_vs_num_c32p10iter5, \
        output_vs_num_mean_c32p10iter5, output_vs_num_var_c32p10iter5] = cur

# close the file
file.close()

# open a file, where you stored the pickled data
file = open('c32p10iter10', 'rb')

# dump information to that file
cur = pickle.load(file)
[opt_true_val_c32p10iter10, running_time_c32p10iter10, number_sampled_c32p10iter10, \
    output_mean_c32p10iter10, output_var_c32p10iter10, output_vs_num_c32p10iter10, \
        output_vs_num_mean_c32p10iter10, output_vs_num_var_c32p10iter10] = cur

# close the file
file.close()

# %%
import numpy as np

max_num = 3000
x = np.arange(0,3000)
fig,ax = plt.subplots()
ax.plot(output_vs_num_mean_c4p5iter5[0:max_num], label = 'c=4,p=5,iter=5', color='tab:blue')
ax.fill_between(x,output_vs_num_mean_c4p5iter5[0:max_num]-2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c4p5iter5[0:max_num]+2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:blue')
ax.plot(output_vs_num_mean_c4p5iter10[0:max_num], label = 'c=4,p=5,iter=10', color='tab:orange')
ax.fill_between(x,output_vs_num_mean_c4p5iter10[0:max_num]-2*output_vs_num_var_c4p5iter10[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c4p5iter10[0:max_num]+2*output_vs_num_var_c4p5iter10[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:orange')
ax.plot(output_vs_num_mean_c4p10iter5[0:max_num], label = 'c=4,p=10,iter=5', color='tab:green')
ax.fill_between(x,output_vs_num_mean_c4p10iter5[0:max_num]-2*output_vs_num_var_c4p10iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c4p10iter5[0:max_num]+2*output_vs_num_var_c4p10iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:green')
ax.plot(output_vs_num_mean_c4p10iter10[0:max_num], label = 'c=4,p=10,iter=10', color='tab:red')
ax.fill_between(x,output_vs_num_mean_c4p10iter10[0:max_num]-2*output_vs_num_var_c4p10iter10[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c4p10iter10[0:max_num]+2*output_vs_num_var_c4p10iter10[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:red')
ax.plot(output_vs_num_mean_c32p5iter5[0:max_num], label = 'c=32,p=5,iter=5', color='tab:purple')
ax.fill_between(x,output_vs_num_mean_c32p5iter5[0:max_num]-2*output_vs_num_var_c32p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c32p5iter5[0:max_num]+2*output_vs_num_var_c32p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:purple')
ax.plot(output_vs_num_mean_c32p5iter10[0:max_num], label = 'c=32,p=5,iter=10', color='tab:brown')
ax.fill_between(x,output_vs_num_mean_c32p5iter10[0:max_num]-2*output_vs_num_var_c32p5iter10[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c32p5iter10[0:max_num]+2*output_vs_num_var_c32p5iter10[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:brown')
ax.plot(output_vs_num_mean_c32p10iter5[0:max_num], label = 'c=32,p=10,iter=5', color='tab:pink')
ax.fill_between(x,output_vs_num_mean_c32p10iter5[0:max_num]-2*output_vs_num_var_c32p10iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c32p10iter5[0:max_num]+2*output_vs_num_var_c32p10iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:pink')
ax.plot(output_vs_num_mean_c32p10iter10[0:max_num], label = 'c=32,p=10,iter=10', color='tab:olive')
ax.fill_between(x,output_vs_num_mean_c32p10iter10[0:max_num]-2*output_vs_num_var_c32p10iter10[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c32p10iter10[0:max_num]+2*output_vs_num_var_c32p10iter10[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:olive')

ax.set_xlabel('Number of simulations / 10')
ax.set_ylabel('True optimality gap')
ax.set_ylim([0,15])

ax.legend()
plt.savefig('comparison_num.png')

# %%
import numpy as np

max_num = 4000
x = np.arange(0,4000)
fig,ax = plt.subplots()
ax.plot(output_vs_num_mean_c4p5iter5[0:max_num], label = 'c=4,p=5,iter=5', color='tab:blue')
ax.fill_between(x,output_vs_num_mean_c4p5iter5[0:max_num]-2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c4p5iter5[0:max_num]+2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:blue')
ax.plot(output_vs_num_mean_c8p5iter5[0:max_num], label = 'c=8,p=5,iter=5', color='tab:orange')
ax.fill_between(x,output_vs_num_mean_c8p5iter5[0:max_num]-2*output_vs_num_var_c8p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c8p5iter5[0:max_num]+2*output_vs_num_var_c8p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:orange')
ax.plot(output_vs_num_mean_c16p5iter5[0:max_num], label = 'c=16,p=5,iter=5', color='tab:green')
ax.fill_between(x,output_vs_num_mean_c16p5iter5[0:max_num]-2*output_vs_num_var_c16p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c16p5iter5[0:max_num]+2*output_vs_num_var_c16p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:green')
ax.plot(output_vs_num_mean_c32p5iter5[0:max_num], label = 'c=32,p=5,iter=5', color='tab:purple')
ax.fill_between(x,output_vs_num_mean_c32p5iter5[0:max_num]-2*output_vs_num_var_c32p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c32p5iter5[0:max_num]+2*output_vs_num_var_c32p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:purple')

ax.set_xlabel('Number of simulations / 10')
ax.set_ylabel('True optimality gap')
ax.set_ylim([0,15])

ax.legend()
plt.savefig('comparison_num.png')

# %%
import numpy as np

max_num = 200
x = np.arange(0,200)
fig,ax = plt.subplots()
ax.plot(output_vs_num_mean_c4p5iter5[0:max_num], label = 'c=4,p=5,iter=5', color='tab:blue')
ax.fill_between(x,output_vs_num_mean_c4p5iter5[0:max_num]-2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
    output_vs_num_mean_c4p5iter5[0:max_num]+2*output_vs_num_var_c4p5iter5[0:max_num]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:blue')
ax.plot(output_vs_num_mean_c8p5iter5[0:max_num*2:2], label = 'c=8,p=5,iter=5', color='tab:orange')
ax.fill_between(x,output_vs_num_mean_c8p5iter5[0:max_num*2:2]-2*output_vs_num_var_c8p5iter5[0:max_num*2:2]/np.sqrt(100), \
    output_vs_num_mean_c8p5iter5[0:max_num*2:2]+2*output_vs_num_var_c8p5iter5[0:max_num*2:2]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:orange')
ax.plot(output_vs_num_mean_c16p5iter5[0:max_num*4:4], label = 'c=16,p=5,iter=5', color='tab:green')
ax.fill_between(x,output_vs_num_mean_c16p5iter5[0:max_num*4:4]-2*output_vs_num_var_c16p5iter5[0:max_num*4:4]/np.sqrt(100), \
    output_vs_num_mean_c16p5iter5[0:max_num*4:4]+2*output_vs_num_var_c16p5iter5[0:max_num*4:4]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:green')
ax.plot(output_vs_num_mean_c32p5iter5[0:max_num*8:8], label = 'c=32,p=5,iter=5', color='tab:purple')
ax.fill_between(x,output_vs_num_mean_c32p5iter5[0:max_num*8:8]-2*output_vs_num_var_c32p5iter5[0:max_num*8:8]/np.sqrt(100), \
    output_vs_num_mean_c32p5iter5[0:max_num*8:8]+2*output_vs_num_var_c32p5iter5[0:max_num*8:8]/np.sqrt(100), \
        alpha=0.2, facecolor='tab:purple')

ax.set_xlabel('Number of simulations per core / 10')
ax.set_ylabel('True optimality gap')
ax.set_ylim([0,15])

ax.legend()
plt.savefig('comparison_num.png')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
iter = 100
x = np.array([4, 8, 16, 32])  # X values
y = np.array([output_vs_num_mean_c4p5iter5[iter], output_vs_num_mean_c8p5iter5[2*iter],\
    output_vs_num_mean_c16p5iter5[4*iter], output_vs_num_mean_c32p5iter5[8*iter]])  # Mean values of Y
e = np.array([2*output_vs_num_var_c4p5iter5[iter]/np.sqrt(100),\
    2*output_vs_num_var_c8p5iter5[2*iter]/np.sqrt(100),\
        2*output_vs_num_var_c16p5iter5[4*iter]/np.sqrt(100),\
            2*output_vs_num_var_c32p5iter5[8*iter]/np.sqrt(100)])  # Standard deviation of Y

# Plotting the sticks with error bars
plt.errorbar(x, y, yerr=e, fmt='o', linestyle='-', ecolor='red', capsize=5)

# Adding horizontal caps to the error bars
for i in range(len(x)):
    plt.plot([x[i]-0.1, x[i]+0.1], [y[i]+e[i], y[i]+e[i]], color='red')
    plt.plot([x[i]-0.1, x[i]+0.1], [y[i]-e[i], y[i]-e[i]], color='red')

plt.xlabel('Number of cores')
plt.ylabel('True optimality gap')
plt.title('Plot for 1000 simulations per core')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
iter = 200
x = np.array([4, 8, 16, 32])  # X values
y = np.array([output_vs_num_mean_c4p5iter5[iter], output_vs_num_mean_c8p5iter5[2*iter],\
    output_vs_num_mean_c16p5iter5[4*iter], output_vs_num_mean_c32p5iter5[8*iter]])  # Mean values of Y
e = np.array([2*output_vs_num_var_c4p5iter5[iter]/np.sqrt(100),\
    2*output_vs_num_var_c8p5iter5[2*iter]/np.sqrt(100),\
        2*output_vs_num_var_c16p5iter5[4*iter]/np.sqrt(100),\
            2*output_vs_num_var_c32p5iter5[8*iter]/np.sqrt(100)])  # Standard deviation of Y

# Plotting the sticks with error bars
plt.errorbar(x, y, yerr=e, fmt='o', linestyle='-', ecolor='red', capsize=5)

# Adding horizontal caps to the error bars
for i in range(len(x)):
    plt.plot([x[i]-0.1, x[i]+0.1], [y[i]+e[i], y[i]+e[i]], color='red')
    plt.plot([x[i]-0.1, x[i]+0.1], [y[i]-e[i], y[i]-e[i]], color='red')

plt.xlabel('Number of cores')
plt.ylabel('True optimality gap')
plt.title('Plot for 2000 simulations per core')
plt.show()

# %%
[cur_opt_sol, cur_opt_true_val, cur_opt_val, cur_num_sampled, cur_num_reps, \
        cur_opt_reg, cur_opt_sol_reg, cur_max_CEI_reg, cur_reg_CEI_max_val, cur_total_opt_val, \
            cur_sampled_in_opt_reg, cur_total_max_CEI, cur_run_time, time_record] = cur

# %%
print(cur.opt_true_val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/hm/7nf3ljf15m50d7c6x0d77zcc0000gn/T/ipykernel_32293/3173321843.py in <module>
# ----> 1 print(cur.opt_true_val)
#
# AttributeError: 'list' object has no attribute 'opt_true_val'

# %%
import pickle
# package for plotting
import matplotlib.pyplot as plt

# open a file, where you stored the pickled data
file = open('seed2', 'rb')

# dump information to that file
cur = pickle.load(file)

# close the file
file.close()

# %%
[cur_opt_sol, cur_opt_true_val, cur_opt_val, cur_num_sampled, cur_num_reps, \
        cur_opt_reg, cur_opt_sol_reg, cur_max_CEI_reg, cur_reg_CEI_max_val, cur_total_opt_val, \
            cur_sampled_in_opt_reg, cur_total_max_CEI, cur_run_time] = cur

# %%
print(cur_opt_true_val[0:50])
# Out:
# [[2.80000000e+01 3.91412735e-01 2.50000000e+01]
#  [2.43125000e+01 7.50729465e+00 5.60000000e+01]
#  [2.43125000e+01 1.45910950e+01 8.70000000e+01]
#  [2.43125000e+01 2.17083030e+01 1.27000000e+02]
#  [2.43125000e+01 2.87963958e+01 1.67000000e+02]
#  [2.43125000e+01 1.08083929e+02 2.07000000e+02]
#  [2.43125000e+01 1.15131641e+02 2.49000000e+02]
#  [2.43125000e+01 1.22187557e+02 2.88000000e+02]
#  [2.43125000e+01 1.29306656e+02 3.23000000e+02]
#  [2.43125000e+01 1.36384137e+02 3.58000000e+02]
#  [1.73125000e+01 2.23039025e+02 3.96000000e+02]
#  [1.73125000e+01 2.32232472e+02 4.41000000e+02]
#  [1.60000000e+01 2.41365298e+02 4.77000000e+02]
#  [1.60000000e+01 2.50460082e+02 5.12000000e+02]
#  [1.60000000e+01 2.59539984e+02 5.42000000e+02]
#  [1.60000000e+01 3.35769248e+02 5.72000000e+02]
#  [1.60000000e+01 3.42930094e+02 6.17000000e+02]
#  [7.00000000e+00 3.50040241e+02 6.52000000e+02]
#  [7.00000000e+00 3.57159257e+02 6.87000000e+02]
#  [7.00000000e+00 3.64283828e+02 7.19000000e+02]
# ...

# %%
import pickle
# package for plotting
import matplotlib.pyplot as plt

# open a file, where you stored the pickled data
file = open('seed1', 'rb')

# dump information to that file
cur = pickle.load(file)

# close the file
file.close()

[cur_opt_sol, cur_opt_true_val, cur_opt_val, cur_num_sampled, cur_num_reps, \
        cur_opt_reg, cur_opt_sol_reg, cur_max_CEI_reg, cur_reg_CEI_max_val, cur_total_opt_val, \
            cur_sampled_in_opt_reg, cur_total_max_CEI, cur_run_time] = cur

# %%
print(cur_opt_true_val)
# Out:
# [[2.80000000e+01 3.91412735e-01 2.50000000e+01]
#  [2.43125000e+01 7.50729465e+00 5.60000000e+01]
#  [2.43125000e+01 1.45910950e+01 8.70000000e+01]
#  ...
#  [0.00000000e+00 2.28164085e+04 5.65470000e+04]
#  [0.00000000e+00 2.28201014e+04 5.65650000e+04]
#  [0.00000000e+00 2.28237858e+04 5.65830000e+04]]

# %%
plt.plot(cur_opt_true_val[:,0])
plt.savefig('cur_opt_true_val.png')
plt.xlabel('Iteration')
plt.ylabel('Optimality gap')
# plt.close()
# Out:
# Text(46.972222222222214, 0.5, 'Optimality gap')

# %%
plt.plot(cur_opt_true_val[:,1])
plt.savefig('cur_opt_true_val.png')
plt.xlabel('Iteration')
plt.ylabel('Cumulate Time (seconds)')
# plt.close()
# Out:
# Text(20.347222222222214, 0.5, 'Cumulate Time (seconds)')

# %%
plt.plot(cur.num_sampled)
plt.savefig('cur_num_sampled.png')
plt.close()

# %%
plt.plot(cur.opt_reg[1:50])
plt.savefig('cur_optimal_region.png')
plt.close()

# %%
plt.plot(cur.opt_sol_reg[1:50])
plt.savefig('cur_optimal_solution_region.png')
plt.close()

# %%
plt.plot(cur.num_reps/10)
plt.savefig('cur_number_of_replications.png')
plt.close()

# %%
import pickle
# package for plotting
import matplotlib.pyplot as plt

# %%
import numpy as np
output_vs_time = np.zeros([2800,50])
output_vs_num = np.zeros([10000,50])

# %%
import time
class HistoryData:
    def __init__(self, dim):

        # region layer
        self.opt_reg = np.empty((0, 3))     # current optimal region (with smallest region output)
        self.opt_sol_reg = np.empty([])   # region contains the current optimal solution
        self.max_CEI_reg = np.empty([])   # region that has the largest CEI value
        self.reg_CEI_max_val = np.empty([])   # the largest region-layer CEI value
        self.sampled_in_opt_reg = np.empty([])    # the number of sampled solutions in the opt region (5,5,5) index = 665
        self.num_sampled_regions = np.empty([])    # number of sampled regions
        
        # solution layer
        self.opt_sol = np.empty((0, dim), np.int32)  # current optimal solution 
        self.opt_val = np.empty((0, 3))     # current optimal value
        self.opt_true_val = np.empty((0, 3))    # current true value at optimal solution
        self.num_sampled = np.empty([])    # number of sampled solutions
        self.num_reps = np.empty([])      # number of total replications
        self.run_time = np.empty([])      # running time 
        self.total_opt_val = np.array([])       # !!! to check if it's same as cur_opt_true_val
        self.total_max_CEI = np.array([])       # record the CEI value at iterations in the solution layer
        
        # records in each visited region (reg)

        self.region = np.array([])
        self.max_CEI_in_reg = np.array([])      # the max CEI value in each visited region
        self.sol_opt_in_reg = np.array([])      # the true objectivee function val in each visted region
        self.num_sampled_in_reg = np.array([])     # the number of sampled solutions in each visited region
        self.num_reps_in_reg = np.array([])       # the number of replications ran in each visited region

        self.shift_vector = np.array([])  # shift vector at each period
        self.beta = np.array([])     # current GMRF mean hyperparameter
        self.theta = np.array([])   # current single-layer hyperparameters
        self.tau = np.array([])    # current region-layer hyperparameters
    
    ##########################################################################################
    def update_optimum(self, start_time, total_num_visited, true_obj_func, opt_reg, opt_sol_reg, opt_val, orig_opt_sol, num_sampled_in_opt_reg):
        ## update the region-layer and solution-layer optimum

        # -region-layer optimum
        temp_array = np.array([opt_reg, time.time()-start_time, total_num_visited])
        self.opt_reg = np.append(self.opt_reg, temp_array.reshape(1,len(temp_array)), axis = 0)       # record

        # record the current optimal solution and the region-layer node that contains the current optimal solution
        self.opt_sol_reg = np.append(self.opt_sol_reg, opt_sol_reg)
        self.opt_sol = np.append(self.opt_sol, orig_opt_sol.reshape(1,len(orig_opt_sol)), axis = 0)   # current optimal solution 
        temp_array = np.array([opt_val, time.time()-start_time, total_num_visited])
        self.opt_val = np.append(self.opt_val, temp_array.reshape(1,len(temp_array)), axis = 0)     # 1*3 
        temp_array = np.array([true_obj_func(orig_opt_sol - 5), time.time()-start_time, total_num_visited])
        self.opt_true_val = np.append(self.opt_true_val, temp_array.reshape(1,len(temp_array)), axis = 0)    # [-5, 5]

        # print out the current optimum
        print('current optimal solution', orig_opt_sol)
        print('current opt: ', opt_val, ', current opt true: ', true_obj_func(orig_opt_sol - 5))

        # record the number of sampled solutions in optimal region
        self.sampled_in_opt_reg = np.append(self.sampled_in_opt_reg, num_sampled_in_opt_reg)

# %%
for seed in range(1,51):
    # open a file, where you stored the pickled data
    file = open('asyn_seed_%s' %str(seed), 'rb')

    # dump information to that file
    cur = pickle.load(file)

    # close the file
    file.close()

    for i in range(2800):
        for j in range(len(cur.opt_true_val)):
            if cur.opt_true_val[j, 1] > i:
                output_vs_time[i, seed-1] = cur.opt_true_val[j, 0]
                break

    for i in range(10000):
        for j in range(len(cur.opt_true_val)):
            if cur.opt_true_val[j, 2]*1.5 >= i:
                output_vs_num[i, seed-1] = cur.opt_true_val[j, 0]
                break

# %%
plt.plot(output_vs_time[:,1])
plt.savefig('output_vs_time2.png')
plt.close()

# %%
plt.plot(output_vs_num[:,1])
plt.savefig('output_vs_num2.png')
plt.close()

# %%
asyn_output_vs_time_mean = np.average(output_vs_time, axis = 1)
asyn_output_vs_time_var = np.std(output_vs_time, axis = 1)
plt.plot(asyn_output_vs_time_mean)
# plt.savefig('asyn_output_vs_time_mean.png')
# plt.close()

# %%
asyn_output_vs_num_mean = np.average(output_vs_num, axis = 1)
asyn_output_vs_num_var = np.std(output_vs_num, axis = 1)
plt.plot(asyn_output_vs_num_mean)

file = open('asyn_result_old', 'wb')
pickle.dump([asyn_output_vs_time_mean, asyn_output_vs_time_var, asyn_output_vs_num_mean, asyn_output_vs_num_var], file)
file.close()

# plt.savefig('asyn_output_vs_num_mean.png')
# plt.close()

# %%
opt_true_val = np.zeros([500, 34])
running_time = np.zeros([500, 34])
number_sampled = np.zeros([500, 34])

# %%
i = 0
for seed in range(1,48):
    if seed in set([2,4,5,6,8,9,10,13,15,17,18,19,20,21,23,24,25,26,28,29,30,31,32,33,34,35,37,38,39,40,43,44,45,46]):
        file = open('seed%s' %str(seed), 'rb')
        output = pickle.load(file)
        [cur_opt_sol, cur_opt_true_val, cur_opt_val, cur_num_sampled, cur_num_reps, \
            cur_opt_reg, cur_opt_sol_reg, cur_max_CEI_reg, cur_reg_CEI_max_val, cur_total_opt_val, \
                cur_sampled_in_opt_reg, cur_total_max_CEI, cur_run_time] = output
        file.close()

        opt_true_val[0:500, i] = cur_opt_true_val[0:500,0]
        running_time[0:500, i] = cur_opt_true_val[0:500,1]
        number_sampled[0:500, i] = cur_num_reps/ 10
        i += 1

# %%
syn_output_vs_time = np.zeros([2800, 34])
syn_output_vs_num = np.zeros([10000, 34])

for seed in range(34):
    for i in range(2800):
        for j in range(500):
            if running_time[j, seed] > i:
                syn_output_vs_time[i, seed] = opt_true_val[j, seed]
                break
    
    for i in range(10000):
        for j in range(500):
            if number_sampled[j, seed] >= i:
                syn_output_vs_num[i, seed] = opt_true_val[j, seed]
                break

# %%
syn_output_vs_num_mean = np.average(syn_output_vs_num, axis = 1)
syn_output_vs_num_var = np.std(syn_output_vs_num, axis = 1)
syn_output_vs_time_mean = np.average(syn_output_vs_time, axis = 1)
syn_output_vs_time_var = np.std(syn_output_vs_time, axis = 1)

# %%
seq_output_vs_time = np.zeros([2800,50])
seq_output_vs_num = np.zeros([10000,50])

# %%
for seed in range(1,51):
    # open a file, where you stored the pickled data
    file = open('pGMIA_seed%s' %str(seed), 'rb')

    # dump information to that file
    output = pickle.load(file)

    # close the file
    file.close()

    opt_true = output[1]
    time = output[-1]
    num = output[4] / 10

    for i in range(2800):
        for j in range(len(opt_true)):
            if time[j] > i:
                seq_output_vs_time[i,seed-1] = opt_true[j]
                break

    for i in range(10000):
        for j in range(len(opt_true)):
            if num[j] >= i:
                seq_output_vs_num[i,seed-1] = opt_true[j]
                break

# %%
seq_output_vs_time_mean = np.average(seq_output_vs_time, axis = 1)
seq_output_vs_time_var = np.std(seq_output_vs_time, axis = 1)
plt.plot(seq_output_vs_time_mean)
plt.savefig('seq_output_vs_time_mean1.png')
plt.close()

# %%
seq_output_vs_num_mean = np.average(seq_output_vs_num, axis = 1)
seq_output_vs_num_var = np.std(seq_output_vs_num, axis = 1)
plt.plot(seq_output_vs_num_mean)
plt.savefig('seq_output_vs_num_mean1.png')
plt.close()

# %%
from scipy.io import savemat
file_name = 'data.mat'
savemat(file_name, {
    'output_vs_num': output_vs_num,
    'output_vs_time': output_vs_time,
    'seq_output_vs_num': seq_output_vs_num,
    'seq_output_vs_time': seq_output_vs_time
})

# %%
savemat('my_array.mat', {'output_vs_num', output_vs_num})

# %%
x = np.arange(0,2800)
fig,ax = plt.subplots()
ax.plot(asyn_output_vs_time_mean-1, label = 'asynchronous', color='blue')
ax.fill_between(x,asyn_output_vs_time_mean-1-2*asyn_output_vs_time_var/np.sqrt(50), asyn_output_vs_time_mean-1+2*asyn_output_vs_time_var/np.sqrt(50), alpha=0.2, facecolor='blue')
ax.plot(syn_output_vs_time_mean, label = 'synchronous', color='darkorange')
ax.fill_between(x,syn_output_vs_time_mean-2*syn_output_vs_time_var/np.sqrt(10), syn_output_vs_time_mean+2*syn_output_vs_time_var/np.sqrt(10), alpha=0.2, facecolor='darkorange')
ax.plot(seq_output_vs_time_mean, label = 'sequential', color='green')
ax.fill_between(x,seq_output_vs_time_mean-2*seq_output_vs_time_var/np.sqrt(50), seq_output_vs_time_mean+2*seq_output_vs_time_var/np.sqrt(50), alpha=0.2, facecolor='green')

ax.set_xlabel('Wallclock time (seconds)')
ax.set_ylabel('True optimality gap')
ax.set_ylim([0,30])

ax.legend()
plt.savefig('comparison_time.png')

# %%
x = np.arange(0,10000)
fig,ax = plt.subplots()
# ax.plot(asyn_output_vs_num_mean, label = 'parallel')
# ax.plot(seq_output_vs_num_mean, label = 'sequential')

ax.plot(asyn_output_vs_num_mean-1, label = 'asynchronous', color='blue')
ax.fill_between(x,asyn_output_vs_num_mean-1-2*asyn_output_vs_num_var/np.sqrt(50), asyn_output_vs_num_mean-1+2*asyn_output_vs_num_var/np.sqrt(50), alpha=0.2, facecolor='blue')
ax.plot(syn_output_vs_num_mean, label = 'synchronous', color='darkorange')
ax.fill_between(x,syn_output_vs_num_mean-2*syn_output_vs_num_var/np.sqrt(34), syn_output_vs_num_mean+2*syn_output_vs_num_var/np.sqrt(34), alpha=0.2, facecolor='darkorange')
ax.plot(seq_output_vs_num_mean, label = 'sequential', color='green')
ax.fill_between(x,seq_output_vs_num_mean-2*seq_output_vs_num_var/np.sqrt(50), seq_output_vs_num_mean+2*seq_output_vs_num_var/np.sqrt(50), alpha=0.2, facecolor='green')


ax.set_xlabel('Number of visited solutions')
ax.set_ylabel('True optimality gap')
ax.set_ylim([0,30])
ax.legend()
plt.savefig('comparison_num.png')

# %%
# open a file, where you stored the pickled data
file = open('seed_3', 'rb')

# dump information to that file
cur = pickle.load(file)

# close the file
file.close()

print(cur.tau)
plt.plot(cur.opt_reg[:,0])
# plt.savefig('cur_optimal_region.png')
# plt.close()
# Out:
# [[3.99265837e+01 1.11615924e-01 6.31231467e-02 1.95817246e-02]]

# %%
# Out:
# [[1.00000000e-06 1.64647252e-01 2.56842357e-01 4.25279681e-02]]
